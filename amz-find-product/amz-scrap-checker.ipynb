# %% [markdown]
# ## About this project
#
# We want a csv with data about most sold products in amazon, because we want to check in another websites if this products are cheaper and we can re-sell in amazon. To do this, we need specific information like the product model,brand,price, merchants, how often is sold, etc.
#
# I will scrap in a specific main category of products (I already know some other sites selling this products with cheaper prices :D ).
#
# Technologies used:
# - Selenium
# - BeautifulSoup (utils.py)
# - Pandas

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from selenium import webdriver
import pandas as pd
import time
import random
import sys
import os
sys.path.append(os.path.abspath('../'))
from utils import (soup_content_from_url, save_soup)

# %%
import pandas as pd
df = pd.read_csv("mcr-general-13-05-2020.csv")
df.columns = [c.lower() for c in df.columns]
df.head(3)
# Out:
#    ref.mcr      marca                          categoría            ean  \
# 0   993381  THE G-LAB                         Accesorios  3760162062854
# 1  1009242       BenQ  Accesorios / Accesorios Monitores  4718755062063
# 2    39727      Ewent  Accesorios / Accesorios Monitores  8056045871350
#
#       part number                                             nombre  precio  \
# 0  KEYZ CARBON/SP  TECLADO G-LAB MECHANICAL KEYBOARD (KEYZ CARBON...   33.05
# 1    5J.LE710.001                    ACCESORIO KIT PARA MONITOR BENQ   78.00
# 2          EW1280        Ewent Soporte Elevador de Monitor con Cajón   11.36
#
#    canon  precio sin canon stock comentario
# 0    0.0             33.05   111        NaN
# 1    0.0             78.00     2        NaN
# 2    0.0             11.36    46        NaN

# %%
df.stock = df.stock.str.replace("+","").str.strip()
df.stock = df.stock.astype(int)
df_5 = df[df.stock > 5]
df_5 = df_5.reset_index(drop=True)

# %%
print(list(df_5.stock.unique()))
# Out:
# [111, 46, 10, 44, 52, 19, 90, 99, 9, 51, 50, 150, 77, 31, 8, 21, 30, 13, 137, 35, 27, 63, 53, 68, 11, 12, 39, 20, 36, 18, 16, 29, 58, 6, 94, 106, 15, 23, 25, 7, 22, 49, 123, 14, 55, 76, 43, 24, 33, 41, 28, 34, 65, 32, 85, 26, 61, 17, 47, 101, 74, 112, 59, 145, 130, 48, 54, 40, 70, 66, 69, 141, 113, 86, 105, 107, 129, 100, 72, 92, 93, 87, 42, 75, 60, 136, 139, 37, 149, 80, 88, 57, 91, 114, 81, 95, 64, 98, 84, 38, 97, 121, 131, 140, 56, 45, 119, 62, 127, 82, 103, 115, 96, 132, 102, 67, 120, 83, 109, 147, 133, 148, 117, 144, 73, 89, 125, 108, 134, 71, 110, 126, 116, 124, 122, 135, 118, 104, 143, 79, 146, 138]

# %% [markdown]
# ## Scrapping and saving soups

# %%
driver = webdriver.Firefox()

# %%
import urllib
base_url = "https://www.amazon.es"
    
#soups.append(soup_content_from_url(driver, url))

# %%
last_index = 220

# %%
import time
import random

def search_in_amz_with_mcrdf(mcrdf, last_index = 0, limit=100):
    def search_in_amz(keywords):
        params={"k":urllib.parse.quote(keywords),
                "__mk_es_ES":"ÅMÅŽÕÑ",
                "ref":"nb_sb_noss"}

        def create_params(d):
            r = ""
            for k in d.keys():
                r = r+f"{k}={d[k]}&"
            return r[:-1]

        url = base_url+'/s?'+create_params(params)
        return soup_content_from_url(driver,url)
        
    i = last_index
    limit = limit + i
    for i,r in mcrdf[mcrdf.index > last_index].iterrows():
        time.sleep(random.randint(1,5))
        if i > limit:
            break
        print(str(i)+" : "+str(r['ref.mcr'])+"  "+r['part number'])
        keywords = r['part number']
        s = search_in_amz(keywords)
        file_name = str(r['ref.mcr'])
        save_soup(s, file_name)
    return i-1

last_index = search_in_amz_with_mcrdf(df_5, last_index,100)
last_index
# Out:
# 221 : 847261  JDA134
# 222 : 847279  JUA370
# 223 : 847308  JUH377
# 224 : 847316  JUCX05
# 225 : 847324  JUCX06
# 226 : 847332  JCH377
# 227 : 847359  JCA153
# 228 : 847367  JCA111
# 229 : 847375  JUH660
# 230 : 847383  JUH340
# 231 : 847391  JUH470
# 232 : 847404  JUE130
# 233 : 847412  JUP50-E
# 234 : 861433  QMSLS
# 235 : 876580  QMTPP
# 236 : 911453  FBA4074CN
# 237 : 911496  FBA4087TY
# 238 : 911509  FBA4088TY
# 239 : 1330521  AC0570E
# 240 : 39550  EW1255
# 241 : 39814  EW1258
# 242 : 1326297  WP II960A
# 243 : 1330011  MNT200
# 244 : 1330012  MNT300
# 245 : 1330013  MNT202
# 246 : 1330014  MNT302
# 247 : 42985  BXSTS200C
# 248 : 875181  X527DA2OCPG1P5
# 249 : 1321537  R1208WFQYSR
# 250 : 50723  10.10.0401
# 251 : 50729  10.10.0402
# 252 : 51537  QMACUSB
# 253 : 817256  20445
# 254 : 992628  BK-200-U2-BE
# 255 : 992644  BK-50-U2-BE
# 256 : 1323791  BE-DOCK-USBC-MINI
# 257 : 1322088  PW-NB-90-ACER-DELL
# 258 : 1324094  E300696601
# 259 : 39420  EW1203
# 260 : 39826  EW1211
# 261 : 838153  EW1190
# 262 : 1324496  EW1315
# 263 : 1326071  EW1209
# 264 : 51506  QMPB2600CV
# 265 : 51507  QMPB2600CR
# 266 : 51540  QMPB80W
# 267 : 40256  QMPB26BK
# 268 : 849469  QMPB100PLB
# 269 : 974091  QMPWC
# 270 : 1326994  TL-PB20000
# 271 : 40940  21227
# 272 : 40944  21221
# 273 : 51253  CS31UC001BL
# 274 : 52192  TB026NA/EUWT
# 275 : 1328501  GDS4104GL
# 276 : 1328502  VXN4285GL
# 277 : 1328503  VXN4273GL
# 278 : 1328504  VXN4274GL
# 279 : 1329876  VXN4254GL
# 280 : 1329877  VXN4304GL
# 281 : 1331955  SUB-CUT-1CT001
# 282 : 1331956  SUB-CUT-1CT002
# 283 : 1331957  SUB-CUT-1CT003
# 284 : 1331958  SUB-CUT-1CT004
# 285 : 1331959  SUB-CUT-2FC001
# 286 : 1331960  SUB-CUT-2FC002
# 287 : 1331961  SUB-CUT-2FC003
# 288 : 1331962  SUB-CUT-3RE001
# 289 : 1331963  SUB-CUT-3RE002
# 290 : 1331964  SUB-CUT-3RE003
# 291 : 1331965  SUB-CST-5SC001
# 292 : 1331966  SUB-CST-5SC002
# 293 : 1331967  SUB-CST-5SC050
# 294 : 1331968  SUB-CST-5SC051
# 295 : 1331969  SUB-CUT-4TC001
# 296 : 1331970  SUB-CUT-4TC002
# 297 : 1331972  SUB-CUT-4TC004
# 298 : 1331973  SUB-CUT-4TC005
# 299 : 1331974  SUB-CUT-4TC006
# 300 : 1331975  SUB-CUT-4TC007
# 301 : 1331976  SUB-CUE-1EC001
# 302 : 1331977  SUB-CUE-1EC002
# 303 : 1331978  SUB-KT1-USB001
# 304 : 1331979  SUB-KT1-USB002
# 305 : 1331980  SUB-KT1-USB003
# 306 : 1331981  SUB-KT1-USB050
# 307 : 1331982  SUB-KT1-USB051
# 308 : 1331984  SUB-KT2-BT0002
# 309 : 1331985  SUB-KT2-BT0003
# 310 : 1331986  SUB-KT2-BT0004
# 311 : 1331987  SUB-KT2-BTP001
# 312 : 1331988  SUB-KT2-BTP002
# 313 : 1331989  SUB-KT3-BTS001
# 314 : 1331990  SUB-KT3-BTS002
# 315 : 1331991  SUB-KT4-BTPI01
# 316 : 1006885  20058
# 317 : 44104  LY014
# 318 : 44168  LY015
# 319 : 44172  LY019
# 320 : 44183  ZR112
# 320

# %%
df[df['ref.mcr']==1329881]
# Out:
#      ref.mcr   marca                                  categoría  \
# 241  1329881  Xiaomi  Accesorios / Accesorios Smartphone/Tablet
#
#                ean part number                            nombre  precio  \
# 241  6934177713231   VXN4286GL  POWER BANK REDMI 10000MAH XIAOMI     8.7
#
#      canon  precio sin canon  stock comentario   ref.id
# 241    0.0               8.7    150        NaN  1329881

# %% [markdown]
# ## Working with soups

# %%
from amz_search_utils import read_soup,

# %%
from amz_search_utils import AmazonProductSearch
from os import listdir

files = listdir('soups')
amazon_searchs = {}
for f in files:
    ref_mcr = f.replace('.html','')
    soup = read_soup(ref_mcr)
    amazon_searchs[ref_mcr] = AmazonProductSearch(soup)

print(len(files))
print(len(amazon_searchs))
# Out:
# 330

# %%
items = []
for ref_id, amazon_search in amazon_searchs.items():
    for search_item in amazon_search.searchItems():
        item = search_item.to_dict()
        item['ref_id'] = ref_id
        items.append(item)
print(len(items))
print(items[0])
# Out:
# 643
# {'stars': '4,0 de 5 estrellas', 'description': 'Fellowes M-7C - Destructora trituradora de papel, corte en partículas, destruye hasta 7 hojas, uso personal,\xa0tritura tarjetas de crédito, color negro', 'link': '/Fellowes-M-7C-Destructora-trituradora-part%C3%ADculas/dp/B00ADX9KBY/ref=sr_1_1?__mk_es_ES=%C3%85M%C3%85%C5%BD%C3%95%C3%91&dchild=1&keywords=4603101&qid=1590190066&sr=8-1', 'price': '89,99€', 'ref_id': '1321675'}

# %%
save_soup(amazon_searchs['1321675'].soup,'test')

# %%
dfamz = pd.DataFrame(items)
dfamz.head(3)
# Out:
#                 stars                                        description  \
# 0  4,0 de 5 estrellas  Fellowes M-7C - Destructora trituradora de pap...
# 1                 NaN  SUBBLIM KEYTAB Pro Bluetooth Red Funda con Tec...
# 2  4,5 de 5 estrellas  Fellowes - Aceite lubricante para destructoras...
#
#                                                 link   price   ref_id stock
# 0  /Fellowes-M-7C-Destructora-trituradora-part%C3...  89,99€  1321675   NaN
# 1  /SUBBLIM-Bluetooth-Teclado-Samsung-BATER%C3%8D...  44,10€  1331990   NaN
# 2  /Fellowes-Aceite-lubricante-destructoras-papel...   9,49€  1321720   NaN

# %%
ref_ids_in_amz = list(dfamz.ref_id.unique())
len(ref_ids_in_amz)
# Out:
# 166

# %%
ordered = df[~df['ref.mcr'].isin(ref_ids_in_amz)].sort_values(by='precio',ascending=False)
ordered = ordered[ordered.stock > 5]
ordered.head(20)#[ordered.precio < 1000].head(20)
# Out:
#       ref.mcr      marca                                 categoría  \
# 5098  1323042    Samsung                                  Displays
# 5074  1325799         LG                                  Displays
# 5016   986404         LG                                  Displays
# 5014   973398         LG                                  Displays
# 5024   906005         LG                                  Displays
# 6767  1327443       Asus                    Ordenadores / Portátil
# 5013   973380         LG                                  Displays
# 6687   946242     CTOUCH                       Monit. interactivos
# 7010  1331242  Millenium                   Ordenadores / Sobremesa
# 6706  1327332    Samsung                       Monit. interactivos
# 9192  1325032      Intel        Servidores / Procesadores Servidor
# 6582  1331218  Schneider                      Imagen y Sonido / TV
# 6078   959297     Kramer  Gestión de señal / Selectores y Matrices
# 663   1321537      Intel              Accesorios servidores / Rack
# 7025  1329843        MSI                   Ordenadores / Sobremesa
# 5111  1010091    Samsung                                  Displays
# 5087  1013444    Samsung                                  Displays
# 6758  1326027       Asus                    Ordenadores / Portátil
# 6928  1331167        MSI                    Ordenadores / Portátil
# 6705  1327331    Samsung                       Monit. interactivos
#
#                  ean      part number  \
# 5098   8801643908355   LH98QBREBGCXEN
# 5074   8806098538416         98UM3E-B
# 5016   8806098292004         75UH5E-B
# 5014   8806098315871         86UL3E-T
# 5024   8806087657821         75UM3C-B
# 6767   4718017537001  90NR02G1-M01630
# 5013   8806098315864         75UL3E-T
# 6687   8719481480295         10052165
# 7010   3527570068195     R206-A536W-M
# 6706   8801643913397   LH65WMRWBGCXEN
# 9192     BX806956230      BX806956230
# 6582   5943808000283         75SU702K
# 6078   7291063085483      20-70010198
# 663      R1208WFQYSR      R1208WFQYSR
# 7025   4719072694593  9S6-B91561-1007
# 5111   8801643558024   LH46OMNSLGB/EN
# 5087  LH55PHFPMGC/EN   LH55PHFPMGC/EN
# 6758   4718017436144  90NR02E2-M01610
# 6928   4719072702311   9S7-17E711-018
# 6705   8801643914288   LH55WMRWBGCXEN
#
#                                                  nombre   precio  canon  \
# 5098                 SAMSUNG STANDALONE UHD 98" MONITOR  7789.00   0.00
# 5074                             LG MONITOR PRO UHD 98"  6915.00   0.00
# 5016       MONITOR LG PROFESIONAL D-LED 4K 75UH5E-B.AEU  3164.24   0.00
# 5014   MONITOR LG PROFESIONAL D-LED 4K 86UL3E-T.AEU 86"  2681.56   0.00
# 5024       MONITOR LG PROFESIONAL D-LED 4K 75" 75UM3C-B  2105.26   0.00
# 6767  PORTÁTIL GAMING ASUS GX531GXR-AZ063T I7-9750H ...  2031.25   5.45
# 5013   MONITOR LG PROFESIONAL D-LED 4K 75UL3E-T.AEU 75"  2011.17   0.00
# 6687     MONITOR INTYERACTIVO LASER NOVA 65" UHD CTOUCH  1889.41   0.00
# 7010                         CPU GAMING MILLENIUM R3R60  1742.29   5.45
# 6706  MONITOR TACTIL DIGITAL SIGNAGE FHD 65" FLIP 2....  1733.33   0.00
# 9192                          PROCESADOR LGA 3647 INTEL  1706.48   0.00
# 6582           TV SCHNEIDER DLED UHD SMART 75" SMART TV  1640.00   0.00
# 6078  KRAMER 4–Channel 4K60 4:2:0 HDMI over Extended...  1620.07   0.00
# 663        SISTEMA DE SERVIDOR INTEL 986059 R1208WFQYSR  1539.10   0.00
# 7025                CPU INFINITE A 9SD-1007IB BLACK MSI  1496.38   5.45
# 5111  MONITOR SEMI-EXTERIOR/EXTERIOR 46" (OM46N) SAM...  1465.56   0.00
# 5087  SAMSUNG / TELEVISIÓN PLANA DE SEÑALIZACIÓN DIG...  1443.33   0.00
# 6758  PORTÁTIL ASUS GU502GV-AZ038T I7-9750H 16GB 1TB...  1429.19   5.45
# 6928              PORTATIL MSI GP75 LEOPARD 10SEK-018ES  1414.30   5.45
# 6705  MONITOR TACTIL DIGITAL SIGNAGE FHD 55" FLIP 2....  1377.78   0.00
#
#       precio sin canon  stock comentario
# 5098           7789.00      7        NaN
# 5074           6915.00      7        NaN
# 5016           3164.24     21        NaN
# 5014           2681.56     17        NaN
# 5024           2105.26      9        NaN
# 6767           2025.80     27        NaN
# 5013           2011.17      8        NaN
# 6687           1889.41     11        NaN
# 7010           1736.84      6        NaN
# 6706           1733.33      6    NOVEDAD
# 9192           1706.48      6        NaN
# 6582           1640.00      7        NaN
# 6078           1620.07      7        NaN
# 663            1539.10     16        NaN
# 7025           1490.93     15        NaN
# 5111           1465.56     53        NaN
# 5087           1443.33      9        NaN
# 6758           1423.74     11        NaN
# 6928           1408.85     15        NaN
# 6705           1377.78      9    NOVEDAD

# %%
ordered.to_csv('ordered_not_in_amz.csv',index=False)
